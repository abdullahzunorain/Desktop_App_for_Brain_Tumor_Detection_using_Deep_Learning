# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from mpl_toolkits.axes_grid1 import ImageGrid
from tensorflow.keras.applications import EfficientNetV2M
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam,Adamax

# %%
no = ['/kaggle/input/brain-mri-images-for-brain-tumor-detection/no']
yes = ['/kaggle/input/brain-mri-images-for-brain-tumor-detection/yes']
file_p = []
labels = []
dict_lists = [no, yes]
class_labels = ['no', 'yes']

for i, dir_list in enumerate(dict_lists):
     for j in dir_list:
            list_f = os.listdir(j)
            for name in list_f:
                fpath = os.path.join(j, name)
                file_p.append(fpath)
                labels.append(class_labels[i])


failpath = pd.Series(file_p, name="filepaths")
Labelss = pd.Series(labels, name="labels")
data = pd.concat([failpath, Labelss], axis=1)
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                            filepaths labels
# 0  /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 1  /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 2  /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 3  /kaggle/input/brain-mri-images-for-brain-tumor...     no
# 4  /kaggle/input/brain-mri-images-for-brain-tumor...     no

# %%
train_df, test_df = train_test_split(df, test_size=0.25, random_state=42,stratify=df.labels)
train_df, val_df = train_test_split(train_df, test_size=0.15, random_state=42,stratify=train_df.labels)
print(train_df.shape)
print(test_df.shape)
print(val_df.shape)
# Out:
# (160, 2)
# (64, 2)
# (29, 2)

# %%
def enhance_image(image):
    image = cv2.addWeighted(image, 1.5, image, -0.5, 0)

    kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
    image = cv2.filter2D(image, -1, kernel)

    hue = image[:, :, 0]
    saturation = image[:, :, 1]
    value = image[:, :, 2]
    value = np.clip(value * 1.25, 0, 255)

    image[:, :, 2] = value

    return image

# %%
image_gen = ImageDataGenerator(
    rescale=1./255,
    preprocessing_function=lambda image: enhance_image(image))
train = image_gen.flow_from_dataframe(dataframe=train_df, x_col="filepaths", y_col="labels",
                                      target_size=(256,256),
                                      color_mode='rgb',
                                      class_mode="categorical", 
                                      batch_size=32,  # Reduced batch size
                                      shuffle=False)



test = image_gen.flow_from_dataframe(dataframe= test_df,x_col="filepaths", y_col="labels",
                                     target_size=(256,256),
                                     color_mode='rgb',
                                     class_mode="categorical",
                                     batch_size=64,
                                     shuffle= False
                                    )


val = image_gen.flow_from_dataframe(dataframe=val_df, x_col="filepaths", y_col="labels",
                                    target_size=(256,256),
                                    color_mode='rgb',
                                    class_mode="categorical",
                                    batch_size=32,  # Reduced batch size
                                    shuffle=False)
# Out:
# Found 160 validated image filenames belonging to 2 classes.
# Found 64 validated image filenames belonging to 2 classes.
# Found 29 validated image filenames belonging to 2 classes.

# %%
import matplotlib.pyplot as plt

# Define the number of images to display from each class
num_images_per_class = 10

# Get class labels
class_labels = list(train.class_indices.keys())

# Plot images from each class
plt.figure(figsize=(15, 10))
for label in class_labels:
    # Get indices of images belonging to the current class
    indices = train_df[train_df['labels'] == label].index
    
    # Randomly sample a subset of indices if there are more than the desired number of images per class
    indices = np.random.choice(indices, min(num_images_per_class, len(indices)), replace=False)
    
    # Plot images
    for i, idx in enumerate(indices):
        plt.subplot(len(class_labels), num_images_per_class, len(class_labels)*i + class_labels.index(label) + 1)
        plt.imshow(plt.imread(train_df.loc[idx, 'filepaths']))  # Load and plot the image
        plt.title(label)
        plt.axis('off')
plt.show()

# %%
from tensorflow.keras.layers import Dropout, Dense, BatchNormalization
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.models import Model
from tensorflow.keras.applications import Xception

learning_rate = 0.001
base_model = Xception(weights='imagenet', include_top=False, pooling='max')
x = base_model.output
x = BatchNormalization()(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

optimizer = Adamax(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train, epochs=150, validation_data=val)
# Out:
# Epoch 1/150
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# W0000 00:00:1725903317.171046      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - accuracy: 0.6895 - loss: 0.9671 - val_accuracy: 0.3793 - val_loss: 4.2649
# Epoch 2/150
# W0000 00:00:1725903328.556714      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 0.8672 - loss: 0.3412 - val_accuracy: 0.5517 - val_loss: 2.4700
# Epoch 3/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 0.9235 - loss: 0.2155 - val_accuracy: 0.7241 - val_loss: 0.9082
# Epoch 4/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 0.9902 - loss: 0.0573 - val_accuracy: 0.7586 - val_loss: 0.4855
# Epoch 5/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 0.9817 - loss: 0.0912 - val_accuracy: 0.7586 - val_loss: 0.7076
# Epoch 6/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 0.9979 - loss: 0.0136 - val_accuracy: 0.7586 - val_loss: 0.9965
# Epoch 7/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 0.9871 - loss: 0.0989 - val_accuracy: 0.7586 - val_loss: 1.0127
# Epoch 8/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.7586 - val_loss: 0.9493
# Epoch 9/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 0.9966 - loss: 0.0050 - val_accuracy: 0.7931 - val_loss: 0.8513
# Epoch 10/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8276 - val_loss: 0.7676
# Epoch 11/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8276 - val_loss: 0.7056
# Epoch 12/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8276 - val_loss: 0.6700
# Epoch 13/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8276 - val_loss: 0.6460
# Epoch 14/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7931 - val_loss: 0.6233
# Epoch 15/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.7931 - val_loss: 0.5997
# Epoch 16/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7931 - val_loss: 0.5751
# Epoch 17/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 6.5832e-04 - val_accuracy: 0.7931 - val_loss: 0.5551
# Epoch 18/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7931 - val_loss: 0.5430
# Epoch 19/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 1.0000 - loss: 9.0758e-04 - val_accuracy: 0.7931 - val_loss: 0.5374
# Epoch 20/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 6.5603e-04 - val_accuracy: 0.7931 - val_loss: 0.5258
# Epoch 21/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 377ms/step - accuracy: 1.0000 - loss: 6.8333e-04 - val_accuracy: 0.7931 - val_loss: 0.5109
# Epoch 22/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 3.0752e-04 - val_accuracy: 0.7931 - val_loss: 0.4963
# Epoch 23/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 3.8348e-04 - val_accuracy: 0.7931 - val_loss: 0.4843
# Epoch 24/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7931 - val_loss: 0.4629
# Epoch 25/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 1.0000 - loss: 3.8801e-04 - val_accuracy: 0.7931 - val_loss: 0.4447
# Epoch 26/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.8621 - val_loss: 0.3970
# Epoch 27/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 376ms/step - accuracy: 1.0000 - loss: 4.3234e-04 - val_accuracy: 0.8621 - val_loss: 0.3665
# Epoch 28/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8966 - val_loss: 0.3500
# Epoch 29/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 9.9298e-04 - val_accuracy: 0.8966 - val_loss: 0.3448
# Epoch 30/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9310 - val_loss: 0.3403
# Epoch 31/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 3.6883e-04 - val_accuracy: 0.9310 - val_loss: 0.3365
# Epoch 32/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9310 - val_loss: 0.3358
# Epoch 33/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9310 - val_loss: 0.3352
# Epoch 34/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 370ms/step - accuracy: 1.0000 - loss: 2.6993e-04 - val_accuracy: 0.9310 - val_loss: 0.3340
# Epoch 35/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - accuracy: 1.0000 - loss: 4.6372e-04 - val_accuracy: 0.9310 - val_loss: 0.3339
# Epoch 36/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 5.5929e-04 - val_accuracy: 0.9310 - val_loss: 0.3351
# Epoch 37/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 8.2524e-04 - val_accuracy: 0.9310 - val_loss: 0.3369
# Epoch 38/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 6.0910e-04 - val_accuracy: 0.9310 - val_loss: 0.3381
# Epoch 39/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 1.0000 - loss: 3.0102e-04 - val_accuracy: 0.9310 - val_loss: 0.3403
# Epoch 40/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 1.0000 - loss: 4.9247e-04 - val_accuracy: 0.9310 - val_loss: 0.3428
# Epoch 41/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8966 - val_loss: 0.3434
# Epoch 42/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 1.0000 - loss: 3.7638e-04 - val_accuracy: 0.8966 - val_loss: 0.3455
# Epoch 43/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 1.0000 - loss: 6.9601e-04 - val_accuracy: 0.8966 - val_loss: 0.3490
# Epoch 44/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 1.0000 - loss: 5.4093e-04 - val_accuracy: 0.8966 - val_loss: 0.3540
# Epoch 45/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 1.0000 - loss: 7.6610e-04 - val_accuracy: 0.8966 - val_loss: 0.3586
# Epoch 46/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8966 - val_loss: 0.3629
# Epoch 47/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 371ms/step - accuracy: 1.0000 - loss: 1.2971e-04 - val_accuracy: 0.8966 - val_loss: 0.3666
# Epoch 48/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 4.7706e-04 - val_accuracy: 0.8966 - val_loss: 0.3713
# Epoch 49/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 382ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8966 - val_loss: 0.3790
# Epoch 50/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 4.1212e-04 - val_accuracy: 0.8966 - val_loss: 0.3860
# Epoch 51/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 374ms/step - accuracy: 1.0000 - loss: 4.8145e-04 - val_accuracy: 0.8966 - val_loss: 0.3926
# Epoch 52/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 6.0541e-04 - val_accuracy: 0.8966 - val_loss: 0.4017
# Epoch 53/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 1.0000 - loss: 4.0588e-04 - val_accuracy: 0.8966 - val_loss: 0.4101
# Epoch 54/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8966 - val_loss: 0.4162
# Epoch 55/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 1.0301e-04 - val_accuracy: 0.8966 - val_loss: 0.4224
# Epoch 56/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 1.1419e-04 - val_accuracy: 0.8966 - val_loss: 0.4293
# Epoch 57/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 9.1836e-04 - val_accuracy: 0.8966 - val_loss: 0.4330
# Epoch 58/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 9.0653e-05 - val_accuracy: 0.8966 - val_loss: 0.4366
# Epoch 59/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 382ms/step - accuracy: 1.0000 - loss: 2.1505e-04 - val_accuracy: 0.8966 - val_loss: 0.4418
# Epoch 60/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 1.3852e-04 - val_accuracy: 0.8966 - val_loss: 0.4491
# Epoch 61/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 2.8686e-04 - val_accuracy: 0.8966 - val_loss: 0.4556
# Epoch 62/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 382ms/step - accuracy: 1.0000 - loss: 1.6508e-04 - val_accuracy: 0.8966 - val_loss: 0.4621
# Epoch 63/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 7.0677e-05 - val_accuracy: 0.8966 - val_loss: 0.4689
# Epoch 64/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8966 - val_loss: 0.4783
# Epoch 65/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 380ms/step - accuracy: 1.0000 - loss: 7.9024e-05 - val_accuracy: 0.8621 - val_loss: 0.4860
# Epoch 66/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 381ms/step - accuracy: 1.0000 - loss: 2.3348e-04 - val_accuracy: 0.8621 - val_loss: 0.4945
# Epoch 67/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 7.7071e-05 - val_accuracy: 0.8621 - val_loss: 0.5020
# Epoch 68/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 1.0000 - loss: 3.4158e-04 - val_accuracy: 0.8621 - val_loss: 0.5099
# Epoch 69/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 1.0000 - loss: 5.2649e-04 - val_accuracy: 0.8621 - val_loss: 0.5176
# Epoch 70/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8621 - val_loss: 0.5235
# Epoch 71/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 1.1191e-04 - val_accuracy: 0.8621 - val_loss: 0.5292
# Epoch 72/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 1.0000 - loss: 1.9092e-04 - val_accuracy: 0.8276 - val_loss: 0.5358
# Epoch 73/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 3.9185e-05 - val_accuracy: 0.8276 - val_loss: 0.5428
# Epoch 74/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 6.9957e-05 - val_accuracy: 0.8276 - val_loss: 0.5502
# Epoch 75/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 1.0000 - loss: 1.1204e-04 - val_accuracy: 0.8276 - val_loss: 0.5572
# Epoch 76/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 2.8278e-04 - val_accuracy: 0.8276 - val_loss: 0.5650
# Epoch 77/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 1.8199e-04 - val_accuracy: 0.8276 - val_loss: 0.5723
# Epoch 78/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 2.4984e-04 - val_accuracy: 0.8276 - val_loss: 0.5795
# Epoch 79/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 9.9156e-05 - val_accuracy: 0.8276 - val_loss: 0.5837
# Epoch 80/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 1.0000 - loss: 7.0570e-05 - val_accuracy: 0.8276 - val_loss: 0.5884
# Epoch 81/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 5.3039e-05 - val_accuracy: 0.8276 - val_loss: 0.5926
# Epoch 82/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8276 - val_loss: 0.5949
# Epoch 83/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 2.9040e-04 - val_accuracy: 0.8276 - val_loss: 0.5999
# Epoch 84/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 1.0000 - loss: 3.6280e-05 - val_accuracy: 0.8276 - val_loss: 0.6054
# Epoch 85/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 1.0000 - loss: 5.5234e-05 - val_accuracy: 0.8276 - val_loss: 0.6108
# Epoch 86/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 399ms/step - accuracy: 1.0000 - loss: 2.2508e-04 - val_accuracy: 0.8276 - val_loss: 0.6151
# Epoch 87/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 2.1646e-04 - val_accuracy: 0.8276 - val_loss: 0.6155
# Epoch 88/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 1.0000 - loss: 9.9406e-05 - val_accuracy: 0.8276 - val_loss: 0.6171
# Epoch 89/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 4.2327e-05 - val_accuracy: 0.8276 - val_loss: 0.6215
# Epoch 90/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 375ms/step - accuracy: 1.0000 - loss: 6.8722e-05 - val_accuracy: 0.8276 - val_loss: 0.6266
# Epoch 91/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 1.9367e-04 - val_accuracy: 0.8276 - val_loss: 0.6331
# Epoch 92/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 1.0000 - loss: 1.5270e-04 - val_accuracy: 0.8276 - val_loss: 0.6450
# Epoch 93/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 1.5704e-04 - val_accuracy: 0.8276 - val_loss: 0.6575
# Epoch 94/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 9.2133e-05 - val_accuracy: 0.8276 - val_loss: 0.6703
# Epoch 95/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 7.0176e-05 - val_accuracy: 0.8276 - val_loss: 0.6801
# Epoch 96/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 1.0000 - loss: 3.1136e-04 - val_accuracy: 0.8276 - val_loss: 0.6887
# Epoch 97/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 1.1416e-04 - val_accuracy: 0.8276 - val_loss: 0.6957
# Epoch 98/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 385ms/step - accuracy: 1.0000 - loss: 1.8732e-04 - val_accuracy: 0.8276 - val_loss: 0.7033
# Epoch 99/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 372ms/step - accuracy: 1.0000 - loss: 1.2477e-04 - val_accuracy: 0.8276 - val_loss: 0.7095
# Epoch 100/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 3.4546e-04 - val_accuracy: 0.8276 - val_loss: 0.7132
# Epoch 101/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 4.7677e-05 - val_accuracy: 0.8276 - val_loss: 0.7170
# Epoch 102/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 3.4890e-05 - val_accuracy: 0.8276 - val_loss: 0.7209
# Epoch 103/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 1.8421e-04 - val_accuracy: 0.8276 - val_loss: 0.7260
# Epoch 104/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 5.6945e-04 - val_accuracy: 0.8276 - val_loss: 0.7317
# Epoch 105/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 1.5525e-04 - val_accuracy: 0.8276 - val_loss: 0.7374
# Epoch 106/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 1.0000 - loss: 5.5825e-05 - val_accuracy: 0.8276 - val_loss: 0.7424
# Epoch 107/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 1.0000 - loss: 8.2712e-05 - val_accuracy: 0.8276 - val_loss: 0.7458
# Epoch 108/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 7.4997e-04 - val_accuracy: 0.8276 - val_loss: 0.7473
# Epoch 109/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 2.1099e-04 - val_accuracy: 0.8276 - val_loss: 0.7461
# Epoch 110/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 3.2622e-05 - val_accuracy: 0.8276 - val_loss: 0.7467
# Epoch 111/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 3.5148e-04 - val_accuracy: 0.8276 - val_loss: 0.7509
# Epoch 112/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 7.8311e-05 - val_accuracy: 0.8276 - val_loss: 0.7551
# Epoch 113/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 1.0000 - loss: 3.3039e-05 - val_accuracy: 0.8276 - val_loss: 0.7579
# Epoch 114/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 2.3120e-05 - val_accuracy: 0.8276 - val_loss: 0.7597
# Epoch 115/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 1.0000 - loss: 4.2875e-04 - val_accuracy: 0.8276 - val_loss: 0.7611
# Epoch 116/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 5.8363e-04 - val_accuracy: 0.8276 - val_loss: 0.7627
# Epoch 117/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 1.0000 - loss: 7.2105e-04 - val_accuracy: 0.8276 - val_loss: 0.7688
# Epoch 118/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 1.8372e-05 - val_accuracy: 0.8276 - val_loss: 0.7755
# Epoch 119/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 3.7705e-05 - val_accuracy: 0.8276 - val_loss: 0.7794
# Epoch 120/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 4.1883e-05 - val_accuracy: 0.8276 - val_loss: 0.7820
# Epoch 121/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 7.4128e-05 - val_accuracy: 0.8276 - val_loss: 0.7828
# Epoch 122/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 1.0000 - loss: 1.2556e-04 - val_accuracy: 0.8276 - val_loss: 0.7817
# Epoch 123/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 380ms/step - accuracy: 1.0000 - loss: 6.0250e-05 - val_accuracy: 0.8276 - val_loss: 0.7800
# Epoch 124/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 1.0000 - loss: 9.1970e-05 - val_accuracy: 0.8276 - val_loss: 0.7792
# Epoch 125/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 3.2206e-04 - val_accuracy: 0.8276 - val_loss: 0.7756
# Epoch 126/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8276 - val_loss: 0.7786
# Epoch 127/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 1.0000 - loss: 1.3726e-04 - val_accuracy: 0.8276 - val_loss: 0.7817
# Epoch 128/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 2.4826e-04 - val_accuracy: 0.8276 - val_loss: 0.7815
# Epoch 129/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 3.4136e-05 - val_accuracy: 0.8276 - val_loss: 0.7810
# Epoch 130/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 4.3018e-05 - val_accuracy: 0.8276 - val_loss: 0.7802
# Epoch 131/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 1.0000 - loss: 7.8140e-05 - val_accuracy: 0.8276 - val_loss: 0.7795
# Epoch 132/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 6.9358e-05 - val_accuracy: 0.8276 - val_loss: 0.7787
# Epoch 133/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 1.0000 - loss: 7.4755e-05 - val_accuracy: 0.8276 - val_loss: 0.7775
# Epoch 134/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 4.0429e-04 - val_accuracy: 0.8276 - val_loss: 0.7777
# Epoch 135/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 1.6253e-04 - val_accuracy: 0.8276 - val_loss: 0.7763
# Epoch 136/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 4.3249e-05 - val_accuracy: 0.8276 - val_loss: 0.7757
# Epoch 137/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 2.0196e-05 - val_accuracy: 0.8276 - val_loss: 0.7747
# Epoch 138/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 1.0000 - loss: 1.5730e-04 - val_accuracy: 0.8276 - val_loss: 0.7747
# Epoch 139/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 2.4050e-05 - val_accuracy: 0.8276 - val_loss: 0.7741
# Epoch 140/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 2.8911e-05 - val_accuracy: 0.8276 - val_loss: 0.7736
# Epoch 141/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 1.0000 - loss: 7.8903e-05 - val_accuracy: 0.8276 - val_loss: 0.7741
# Epoch 142/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 1.0000 - loss: 7.1033e-05 - val_accuracy: 0.8276 - val_loss: 0.7764
# Epoch 143/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 9.8665e-05 - val_accuracy: 0.8276 - val_loss: 0.7773
# Epoch 144/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 3.6150e-05 - val_accuracy: 0.8276 - val_loss: 0.7779
# Epoch 145/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 7.9174e-04 - val_accuracy: 0.8276 - val_loss: 0.7687
# Epoch 146/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.8276 - val_loss: 0.7908
# Epoch 147/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 2.0467e-04 - val_accuracy: 0.8276 - val_loss: 0.8031
# Epoch 148/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - accuracy: 1.0000 - loss: 1.6680e-04 - val_accuracy: 0.8621 - val_loss: 0.8084
# Epoch 149/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 1.7104e-05 - val_accuracy: 0.8621 - val_loss: 0.8107
# Epoch 150/150
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 375ms/step - accuracy: 1.0000 - loss: 8.7661e-05 - val_accuracy: 0.8621 - val_loss: 0.8105

# %%
# Evaluate the model on test data
loss, accuracy = model.evaluate(test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.8906 - loss: 1.2492
# Test Loss: 1.2492207288742065
# Test Accuracy: 0.890625

# %%
import matplotlib.pyplot as plt
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(train_accuracy, label='Training Accuracy', color='blue')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training Accuracy')
plt.legend()


# Plot validation accuracy
plt.subplot(1, 2, 2)
plt.plot(val_accuracy, label='Validation Accuracy', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()


# Plot training and validation loss
plt.figure(figsize=(14, 5))

# Plot training loss
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss', color='blue')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.legend()

# Plot validation loss
plt.subplot(1, 2, 2)
plt.plot(val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

# Get predictions for the test data
y_pred = model.predict(test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Get true labels for the test data
true_classes = test.classes

# Compute confusion matrix
conf_matrix = confusion_matrix(true_classes, y_pred_classes)

# Plot confusion matrix
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', square=True, 
            xticklabels=test.class_indices.keys(), yticklabels=test.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step

# %% [markdown]
# > **DONE**
